# %% [markdown]
# 1. Increases batch size decreases training time, but decreases the test accuracy at the same time. (Under same epoch)
# 2. DNN has more parameters. Since CNN uses convolution and maxpooling, it can reduce numbers of parameters.

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop, Adam
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        tf.config.experimental.set_visible_devices(gpus[1], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2 Physical GPUs, 1 Logical GPUs

# %%
batch_size = 128
num_classes = 10
epochs = 10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
x_train = x_train.reshape(50000, 3072) 
x_test = x_test.reshape(10000, 3072)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(3072,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               1573376
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 1,841,162
# Trainable params: 1,841,162
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 2s 38us/sample - loss: 2.1237 - accuracy: 0.2488 - val_loss: 1.8571 - val_accuracy: 0.3277
# Epoch 2/10
# 50000/50000 [==============================] - 1s 22us/sample - loss: 1.8664 - accuracy: 0.3249 - val_loss: 1.7923 - val_accuracy: 0.3487
# Epoch 3/10
# 50000/50000 [==============================] - 1s 24us/sample - loss: 1.7875 - accuracy: 0.3563 - val_loss: 1.7290 - val_accuracy: 0.3869
# Epoch 4/10
# 50000/50000 [==============================] - 1s 26us/sample - loss: 1.7416 - accuracy: 0.3736 - val_loss: 1.6727 - val_accuracy: 0.4075
# Epoch 5/10
# 50000/50000 [==============================] - 1s 27us/sample - loss: 1.6970 - accuracy: 0.3906 - val_loss: 1.6074 - val_accuracy: 0.4424
# Epoch 6/10
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.6764 - accuracy: 0.4006 - val_loss: 1.6261 - val_accuracy: 0.4262
# Epoch 7/10
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.6482 - accuracy: 0.4094 - val_loss: 1.6340 - val_accuracy: 0.4265
# Epoch 8/10
# 50000/50000 [==============================] - 1s 30us/sample - loss: 1.6305 - accuracy: 0.4142 - val_loss: 1.5864 - val_accuracy: 0.4386
# Epoch 9/10
# 50000/50000 [==============================] - 1s 30us/sample - loss: 1.6168 - accuracy: 0.4211 - val_loss: 1.5460 - val_accuracy: 0.4612
# Epoch 10/10
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.6011 - accuracy: 0.4281 - val_loss: 1.5560 - val_accuracy: 0.4558
# Test loss: 1.5559919677734375
# Test accuracy: 0.4558

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 6s 114us/sample - loss: 1.7501 - accuracy: 0.3694 - val_loss: 1.4141 - val_accuracy: 0.4949
# Epoch 2/10
# 50000/50000 [==============================] - 4s 87us/sample - loss: 1.3125 - accuracy: 0.5333 - val_loss: 1.1984 - val_accuracy: 0.5810
# Epoch 3/10
# 50000/50000 [==============================] - 4s 83us/sample - loss: 1.1121 - accuracy: 0.6089 - val_loss: 0.9434 - val_accuracy: 0.6688
# Epoch 4/10
# 50000/50000 [==============================] - 4s 83us/sample - loss: 0.9836 - accuracy: 0.6572 - val_loss: 0.8767 - val_accuracy: 0.6957
# Epoch 5/10
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.8882 - accuracy: 0.6902 - val_loss: 0.8679 - val_accuracy: 0.7017
# Epoch 6/10
# 50000/50000 [==============================] - 5s 91us/sample - loss: 0.8249 - accuracy: 0.7124 - val_loss: 0.8917 - val_accuracy: 0.7052
# Epoch 7/10
# 50000/50000 [==============================] - 4s 88us/sample - loss: 0.7696 - accuracy: 0.7333 - val_loss: 0.7638 - val_accuracy: 0.7387
# Epoch 8/10
# 50000/50000 [==============================] - 4s 87us/sample - loss: 0.7349 - accuracy: 0.7437 - val_loss: 0.7595 - val_accuracy: 0.7431
# Epoch 9/10
# 50000/50000 [==============================] - 4s 85us/sample - loss: 0.6979 - accuracy: 0.7569 - val_loss: 0.7084 - val_accuracy: 0.7594
# Epoch 10/10
# 50000/50000 [==============================] - 4s 86us/sample - loss: 0.6676 - accuracy: 0.7714 - val_loss: 0.6943 - val_accuracy: 0.7682
# Test loss: 0.6942537104606629
# Test accuracy: 0.7682

# %%
batch_size = 256

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_7 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_8 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_9 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_10 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_11 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 68us/sample - loss: 1.8884 - accuracy: 0.3208 - val_loss: 1.7248 - val_accuracy: 0.3918
# Epoch 2/10
# 50000/50000 [==============================] - 3s 55us/sample - loss: 1.4770 - accuracy: 0.4759 - val_loss: 1.2189 - val_accuracy: 0.5627
# Epoch 3/10
# 50000/50000 [==============================] - 3s 58us/sample - loss: 1.2586 - accuracy: 0.5548 - val_loss: 1.1143 - val_accuracy: 0.6025
# Epoch 4/10
# 50000/50000 [==============================] - 3s 57us/sample - loss: 1.1172 - accuracy: 0.6073 - val_loss: 1.0860 - val_accuracy: 0.6238
# Epoch 5/10
# 50000/50000 [==============================] - 3s 61us/sample - loss: 1.0084 - accuracy: 0.6473 - val_loss: 0.9286 - val_accuracy: 0.6753
# Epoch 6/10
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.9218 - accuracy: 0.6808 - val_loss: 0.8518 - val_accuracy: 0.7068
# Epoch 7/10
# 50000/50000 [==============================] - 3s 59us/sample - loss: 0.8524 - accuracy: 0.7038 - val_loss: 0.9749 - val_accuracy: 0.6724
# Epoch 8/10
# 50000/50000 [==============================] - 3s 63us/sample - loss: 0.7951 - accuracy: 0.7237 - val_loss: 0.7729 - val_accuracy: 0.7336
# Epoch 9/10
# 50000/50000 [==============================] - 3s 64us/sample - loss: 0.7513 - accuracy: 0.7398 - val_loss: 0.9027 - val_accuracy: 0.7008
# Epoch 10/10
# 50000/50000 [==============================] - 3s 57us/sample - loss: 0.7076 - accuracy: 0.7529 - val_loss: 0.8251 - val_accuracy: 0.7253
# Test loss: 0.8251022629737854
# Test accuracy: 0.7253

# %%
batch_size = 512

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_12 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_13 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_14 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_15 (Activation)   (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1180160
# _________________________________________________________________
# activation_16 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_17 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 3s 60us/sample - loss: 2.0633 - accuracy: 0.2533 - val_loss: 1.9242 - val_accuracy: 0.3042
# Epoch 2/10
# 50000/50000 [==============================] - 2s 42us/sample - loss: 1.7042 - accuracy: 0.3928 - val_loss: 1.4827 - val_accuracy: 0.4617
# Epoch 3/10
# 50000/50000 [==============================] - 2s 42us/sample - loss: 1.5132 - accuracy: 0.4585 - val_loss: 1.4463 - val_accuracy: 0.4901
# Epoch 4/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 1.3882 - accuracy: 0.5061 - val_loss: 1.3707 - val_accuracy: 0.5253
# Epoch 5/10
# 50000/50000 [==============================] - 2s 45us/sample - loss: 1.2740 - accuracy: 0.5497 - val_loss: 1.2802 - val_accuracy: 0.5520
# Epoch 6/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 1.1877 - accuracy: 0.5796 - val_loss: 1.2490 - val_accuracy: 0.5701
# Epoch 7/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 1.1067 - accuracy: 0.6118 - val_loss: 1.0224 - val_accuracy: 0.6436
# Epoch 8/10
# 50000/50000 [==============================] - 2s 44us/sample - loss: 1.0404 - accuracy: 0.6370 - val_loss: 0.9983 - val_accuracy: 0.6529
# Epoch 9/10
# 50000/50000 [==============================] - 2s 42us/sample - loss: 0.9749 - accuracy: 0.6594 - val_loss: 0.9310 - val_accuracy: 0.6742
# Epoch 10/10
# 50000/50000 [==============================] - 2s 46us/sample - loss: 0.9270 - accuracy: 0.6768 - val_loss: 0.8519 - val_accuracy: 0.7061
# Test loss: 0.8519050303459168
# Test accuracy: 0.7061
