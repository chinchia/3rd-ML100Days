# %% [markdown]
# 1. normalization: line 35 ~ line 38
# 2. optimizer = Adadelta
# 3. two convolution layers
# 4. total parameters = 1,199,882

# %%
import tensorflow.keras as keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

print(model.summary())

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 9216)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1179776
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/12
# 60000/60000 [==============================] - 18s 307us/sample - loss: 2.2937 - accuracy: 0.1268 - val_loss: 2.2699 - val_accuracy: 0.2318
# Epoch 2/12
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.2525 - accuracy: 0.2139 - val_loss: 2.2198 - val_accuracy: 0.4559
# Epoch 3/12
# 60000/60000 [==============================] - 2s 39us/sample - loss: 2.2002 - accuracy: 0.3122 - val_loss: 2.1518 - val_accuracy: 0.5898
# Epoch 4/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.1271 - accuracy: 0.4072 - val_loss: 2.0573 - val_accuracy: 0.6620
# Epoch 5/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 2.0287 - accuracy: 0.4775 - val_loss: 1.9294 - val_accuracy: 0.7074
# Epoch 6/12
# 60000/60000 [==============================] - 2s 39us/sample - loss: 1.8975 - accuracy: 0.5372 - val_loss: 1.7613 - val_accuracy: 0.7468
# Epoch 7/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.7369 - accuracy: 0.5731 - val_loss: 1.5591 - val_accuracy: 0.7747
# Epoch 8/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.5609 - accuracy: 0.6069 - val_loss: 1.3500 - val_accuracy: 0.7871
# Epoch 9/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.3967 - accuracy: 0.6324 - val_loss: 1.1634 - val_accuracy: 0.8017
# Epoch 10/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.2540 - accuracy: 0.6543 - val_loss: 1.0108 - val_accuracy: 0.8130
# Epoch 11/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.1438 - accuracy: 0.6729 - val_loss: 0.8936 - val_accuracy: 0.8212
# Epoch 12/12
# 60000/60000 [==============================] - 2s 38us/sample - loss: 1.0550 - accuracy: 0.6939 - val_loss: 0.8035 - val_accuracy: 0.8289
# Test loss: 0.8035280198097229
# Test accuracy: 0.8289
